# %% [markdown]
# ### Hotmart Technical Case: Analysis about Sales Recovery
#
# In **this notebook** I intend use the queries built with SQL for details analysis, generate insights and recomentations.
#
# **Color palette**:
# *   <span style="background-color:#EF4E23; padding: 0.5em; display: inline-block;"></span> Orange: #EF4E23
# *   <span style="background-color:#053D4D; padding: 0.5em; display: inline-block;"></span> Dark Blue: #053D4D
# *   <span style="background-color:#ECEBEB; padding: 0.5em; display: inline-block;"></span> Ice: #ECEBEB
# *   <span style="background-color:#8CA4AC; padding: 0.5em; display: inline-block;"></span> Dark Gray: #8CA4AC
# *   <span style="background-color:#BCCCD4; padding: 0.5em; display: inline-block;"></span> Light Gray: #BCCCD4

# %% [markdown]
# #### 0. Development setup

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading file sales.db, this file is database with tables already data cleaning and validation

# %%
# Load db in pthon
path_db = '../../data/sales.db'
# Creating engine sqlite
engine = create_engine(f"sqlite:///{path_db}")

# %% [markdown]
# Fucntion with propose through of the SQL file execute query and make create of dataframe using pandas

# %%
# Function execute query

def query_execute(path_query):
    # Open file with query
    path_query = path_query

    with open(path_query, 'r') as file:
        query_from_file = file.read()

    # Generate analysis from query content
    with engine.connect() as conn:
        df = pd.read_sql_query(text(query_from_file), conn)

    return df

# %% [markdown]
# Functions to generate charts

# %%
def chart_barh(df_y, df_x, title_name, y_label, x_label, color='#EF4E23'):
    fig, ax = plt.subplots(figsize=(10,5))

    y = df_y
    x = df_x.head(5)
    # Chart with horizontal bars
    hbars = ax.barh(y, x, color=color)

    ax.set_xlabel(x_label)   # label axis x
    ax.set_ylabel(y_label)   # label axis y
    ax.invert_yaxis()        # invert products orders
    ax.set_title(title_name) # title

    # rotules
    ax.bar_label(hbars)
    #borda
    plt.tight_layout()
    plt.show()

def chart_barv(df_x, df_y, title_name, y_label, x_label, color='#EF4E23'):
    fig, ax = plt.subplots(figsize=(10,5))

    x = df_x
    y = df_y
    # Chart with horizontal bars
    vbars = ax.bar(x, y, color=color)

    ax.set_xlabel(x_label)   # label axis x
    ax.set_ylabel(y_label)   # label axis y
    ax.set_title(title_name) # title

    # rotules
    ax.bar_label(vbars)
    #borda
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Pre-Work

# %%
df_complete_table = query_execute('../analysis/complete_table.sql')
display(df_complete_table)
# Out:
#        purchase_id purchase_date  product_id  product_price  service_tax  \
# 0        696733696    2022-06-21   275653577           48.0          7.2
# 1        957560528    2021-01-02   399974968           45.0          4.5
# 2        800828744    2020-07-07   489748266         1000.0        100.0
# 3        964632300    2022-11-24   545252229          210.0         21.0
# 4        830193347    2021-09-05   489748266         1000.0        100.0
# ...            ...           ...         ...            ...          ...
# 10661    289956962    2020-04-04   399974968           45.0          5.4
# 10662    788921762    2021-01-03   489748266         1000.0        100.0
# 10663    345494529    2022-02-04   264261718          560.0         56.0
# 10664    199287415    2022-09-30   399974968           45.0          4.5
# 10665    439221629    2022-12-25   983844542          650.0         65.0
#
#        comission_value  has_coupon  discount  refund  cancelled  ...  \
# 0                 36.0           1       0.1       0          0  ...
# 1                 40.5           0       0.0       1          0  ...
# 2                900.0           0       0.0       0          0  ...
# 3                168.0           1       0.1       0          0  ...
# 4                900.0           0       0.0       0          0  ...
# ...                ...         ...       ...     ...        ...  ...
# 10661             39.6           0       0.0       0          0  ...
# 10662            900.0           0       0.0       0          0  ...
# 10663            504.0           0       0.0       0          0  ...
# 10664             36.0           1       0.1       0          1  ...
# 10665            520.0           1       0.1       0          0  ...
#
#        registry_date  recovery_active  member_area_active deletion_date  \
# 0         2020-01-29                0                   0          None
# 1         2018-05-21                0                   0          None
# 2         2018-10-30                1                   1          None
# 3         2022-09-14                0                   0          None
# 4         2018-10-30                1                   1          None
# ...              ...              ...                 ...           ...
# 10661     2018-05-21                0                   0          None
# 10662     2018-10-30                1                   1          None
# 10663     2021-04-24                1                   0          None
# 10664     2018-05-21                0                   0          None
# 10665     2020-01-02                1                   0          None
#
#                        niche  base_price        type producer_id  \
# 0             Artes e Design        48.0       Ebook          10
# 1      Tecnologia e Inovação        45.0       Ebook           1
# 2                  Marketing      1000.0  Assinatura           1
# 3          Educação Infantil       210.0       Curso           4
# 4                  Marketing      1000.0  Assinatura           1
# ...                      ...         ...         ...         ...
# 10661  Tecnologia e Inovação        45.0       Ebook           1
# 10662              Marketing      1000.0  Assinatura           1
# 10663               Financas       560.0       Curso           8
# 10664  Tecnologia e Inovação        45.0       Ebook           1
# 10665       Empreendedorismo       650.0  Assinatura           3
#
#        registry_date   country
# 0         2020-01-12    BRASIL
# 1         2018-02-01    BRASIL
# 2         2018-02-01    BRASIL
# 3         2021-01-02  COLOMBIA
# 4         2018-02-01    BRASIL
# ...              ...       ...
# 10661     2018-02-01    BRASIL
# 10662     2018-02-01    BRASIL
# 10663     2019-01-11    BRASIL
# 10664     2018-02-01    BRASIL
# 10665     2020-01-02    BRASIL
#
# [10666 rows x 23 columns]

# %%
df_complete_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10666 entries, 0 to 10665
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   purchase_id         10666 non-null  int64
#  1   purchase_date       10666 non-null  object
#  2   product_id          10666 non-null  int64
#  3   product_price       10666 non-null  float64
#  4   service_tax         10666 non-null  float64
#  5   comission_value     10666 non-null  float64
#  6   has_coupon          10666 non-null  int64
#  7   discount            10666 non-null  float64
#  8   refund              10666 non-null  int64
#  9   cancelled           10666 non-null  int64
#  10  chargeback          10666 non-null  int64
#  11  product_id          10666 non-null  int64
#  12  producer_id         10666 non-null  int64
#  13  registry_date       10666 non-null  object
#  14  recovery_active     10666 non-null  int64
#  15  member_area_active  10666 non-null  int64
#  16  deletion_date       180 non-null    object
#  17  niche               10666 non-null  object
#  18  base_price          10666 non-null  float64
#  19  type                10666 non-null  object
#  20  producer_id         10666 non-null  int64
#  21  registry_date       10666 non-null  object
#  22  country             10666 non-null  object
# dtypes: float64(5), int64(11), object(7)
# memory usage: 1.9+ MB

# %%
df_complete_table.describe().T
# Out:
#                       count          mean           std          min  \
# purchase_id         10666.0  5.761821e+08  2.351589e+08  168168299.0
# product_id          10666.0  5.126968e+08  2.395417e+08  218834610.0
# product_price       10666.0  5.112265e+02  5.283548e+02         30.0
# service_tax         10666.0  5.682606e+01  5.992343e+01          3.0
# comission_value     10666.0  4.231427e+02  4.413923e+02         16.5
# has_coupon          10666.0  4.028689e-01  4.904978e-01          0.0
# discount            10666.0  6.069754e-02  8.522572e-02          0.0
# refund              10666.0  7.734858e-02  2.671563e-01          0.0
# cancelled           10666.0  1.136321e-01  3.173788e-01          0.0
# chargeback          10666.0  5.212826e-02  2.222961e-01          0.0
# product_id          10666.0  5.126968e+08  2.395417e+08  218834610.0
# producer_id         10666.0  5.004500e+00  4.410742e+00          1.0
# recovery_active     10666.0  4.317457e-01  4.953427e-01          0.0
# member_area_active  10666.0  2.958935e-01  4.564648e-01          0.0
# base_price          10666.0  5.112265e+02  5.283548e+02         30.0
# producer_id         10666.0  5.004500e+00  4.410742e+00          1.0
#
#                              25%          50%          75%          max
# purchase_id         3.722836e+08  577322686.0  777877384.0  986867362.0
# product_id          3.434116e+08  399974968.0  719732475.0  983844542.0
# product_price       4.800000e+01        390.0        950.0       1984.0
# service_tax         5.400000e+00         39.0        100.0        297.6
# comission_value     4.050000e+01        324.8        720.0       1785.6
# has_coupon          0.000000e+00          0.0          1.0          1.0
# discount            0.000000e+00          0.0          0.1          0.3
# refund              0.000000e+00          0.0          0.0          1.0
# cancelled           0.000000e+00          0.0          0.0          1.0
# chargeback          0.000000e+00          0.0          0.0          1.0
# product_id          3.434116e+08  399974968.0  719732475.0  983844542.0
# producer_id         1.000000e+00          3.0          8.0         14.0
# recovery_active     0.000000e+00          0.0          1.0          1.0
# member_area_active  0.000000e+00          0.0          1.0          1.0
# base_price          4.800000e+01        390.0        950.0       1984.0
# producer_id         1.000000e+00          3.0          8.0         14.0

# %%
matrix_corr = df_complete_table[['comission_value', 'service_tax', 'discount', 'refund', 'cancelled', 'chargeback', 'recovery_active', 'member_area_active']].corr()

plt.figure(figsize=(12, 6))

sns.heatmap(
    matrix_corr,
    annot=True,     
    fmt='.2f',
    cmap='coolwarm',
    linewidths=.5,
    center=0,
    cbar=True,
    square=True
)

plt.title('Correlation between numeric variable for sales complete table', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**: There are correlation between:
# - member_are_active and recovery_active: It indicated member_are_active equals true, there are more products using recovery_active
# - member_are_active and commission_value:  It indicated member_are_active equals true, there is tendency to increase comission_value
# - recovery_active and commission_value: Make sense, because the last insights above

# %% [markdown]
# #### 1. Analysis of Products

# %%
df_products = query_execute('../analysis/1_top_products_sales.sql')
display(df_products)
# Out:
#    product_id                  niche  qtd_vendas
# 0   983844542       Empreendedorismo         331
# 1   719732475  Tecnologia e Inovação         169
# 2   260868848    Saúde e Alimentação         148
# 3   324917616                Viagens          92
# 4   348532296               Financas          49

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  5 non-null      int64
#  1   niche       5 non-null      object
#  2   qtd_vendas  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
chart_barh(
    df_products['product_id'].astype(str), 
    df_products['qtd_vendas'],
    'The best-selling products of each niche',
    'Product Id',
    'Quantity of Products'
)

# %% [markdown]
# **Insights**: It was possible to check best-selling products of each niche, the niche Entrepreneurship and Innovation & Technologies is better than other categories, this tendency can be a strong start point for to prioritize action in the future. Bellow, I intent analyze sales and sales not completed per product type.

# %%
df_group_sales_not_completed = df_complete_table[(df_complete_table['refund'] == 1) | (df_complete_table['cancelled'] == 1) | (df_complete_table['chargeback'] == 1)]

display(df_complete_table.groupby(by='type').size())
display(df_group_sales_not_completed.groupby(by='type').size())

rate_not_completed = df_group_sales_not_completed.groupby(by='type').size()/ df_complete_table.groupby(by='type').size()*100

rate_not_completed.sort_values(ascending=False, inplace=True)
display(rate_not_completed)
# Out:
# type
# Assinatura        3812
# Curso             1401
# Ebook             5083
# Palestra           358
# Produto Físico      12
# dtype: int64
# type
# Assinatura         713
# Curso              266
# Ebook             1401
# Palestra            81
# Produto Físico       2
# dtype: int64
# type
# Ebook             27.562463
# Palestra          22.625698
# Curso             18.986438
# Assinatura        18.704092
# Produto Físico    16.666667
# dtype: float64

# %%
chart_barh(
    rate_not_completed.index, 
    rate_not_completed,
    'The Sales Not Completed Rate per Products Type',
    'Product Type',
    'Sales Not Completed Rate'
)

# %% [markdown]
# **Insights**: It was possible to check 'Ebook' and 'Palestra' have the biggest Sales Not Completed Rate, I think can be because it's products with acess all content in the shopping moment, and in Brazil for example, there is law of refund until seven days. I try verify bellow:

# %%
df_group_sales_refund = df_complete_table[(df_complete_table['refund'] == 1)]
rate_refund = df_group_sales_refund.groupby(by='type').size()/ df_complete_table.groupby(by='type').size()*100

rate_refund.sort_values(ascending=False, inplace=True)
display(rate_refund)
# Out:
# type
# Produto Físico    16.666667
# Ebook              9.443242
# Palestra           6.703911
# Curso              6.352605
# Assinatura         6.033578
# dtype: float64

# %% [markdown]
# **Insights**: 'Ebook' and 'Palestra' are in second and third position in refund, this indicated more refund to this products, but the 'Produto Físico' is first position, with total rate of Sales Not Completed only category refund, it can be explain because the people shopping the products without contact phisics and there are more possibility of regret.

# %% [markdown]
# #### 2. Analysis of Producers

# %%
df_producers = query_execute('../analysis/2_top_producer.sql')
display(df_producers)
# Out:
#    producer_id country  total_commission
# 0           13  BRASIL           1458139
# 1            3  BRASIL            292171
# 2            6  MEXICO            262550
# 3            7  BRASIL            128060
# 4            5  BRASIL             45328

# %%
df_producers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   producer_id       5 non-null      int64
#  1   country           5 non-null      object
#  2   total_commission  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
chart_barh(
    df_producers['producer_id'].astype(str), 
    df_producers['total_commission']/1000, 
    'The 5 producers from 2019 onwards using recovery with highest commission', 
    'Producers Id', 
    'Total Commission (Thous.)'
)

# %% [markdown]
# **Insights**: It is possible to observe the largest producer (13) well above the others with 1,458,139 sales, against the second with 292,171 sales. This is it indicate that strategies this producer is working very well, it should be interesting to analyze with more details what are reason, and to try replicate some actions all producers.

# %% [markdown]
# #### 3. Analysis of Week Sales

# %%
df_sales_week = query_execute('../analysis/3_sales_per_week.sql')
display(df_sales_week)
# Out:
#     year desc_weekday  previous_sales  currently_sales  variation_sales
# 0   2020       Sunday             NaN              331              NaN
# 1   2021       Sunday           331.0              377            12.20
# 2   2022       Sunday           377.0              428            11.92
# 3   2020       Monday             NaN              203              NaN
# 4   2021       Monday           203.0              238            14.71
# 5   2022       Monday           238.0              314            24.20
# 6   2020      Tuesday             NaN              211              NaN
# 7   2021      Tuesday           211.0              198            -6.57
# 8   2022      Tuesday           198.0              345            42.61
# 9   2020    Wednesday             NaN              157              NaN
# 10  2021    Wednesday           157.0              158             0.63
# 11  2022    Wednesday           158.0              227            30.40
# 12  2020     Thursday             NaN              166              NaN
# 13  2021     Thursday           166.0              149           -11.41
# 14  2022     Thursday           149.0              253            41.11
# 15  2020       Friday             NaN              253              NaN
# 16  2021       Friday           253.0              262             3.44
# 17  2022       Friday           262.0              374            29.95
# 18  2020     Saturday             NaN              382              NaN
# 19  2021     Saturday           382.0              406             5.91
# 20  2022     Saturday           406.0              594            31.65

# %%
df_sales_week.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             21 non-null     int64
#  1   desc_weekday     21 non-null     object
#  2   previous_sales   14 non-null     float64
#  3   currently_sales  21 non-null     int64
#  4   variation_sales  14 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 972.0+ bytes

# %% [markdown]
# Plot stacked bars to analyze sales on the time

# %%
df_pivot = df_sales_week.pivot(index="desc_weekday", columns="year", values="currently_sales").fillna(0)
df_pivot = df_pivot.reindex(["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])  # Ordenação dos dias

fig, ax = plt.subplots(figsize=(10, 5))
bottom = np.zeros(len(df_pivot))  # initial base zero
colors = {2020: "#EF4E23", 2021: "#053D4D", 2022: "#8CA4AC"}  # year collors

for year in [2020, 2021, 2022]:
    ax.bar(df_pivot.index, df_pivot[year], bottom=bottom, label=f"Ano {year}", color=colors[year])
    bottom += df_pivot[year]  # Update the base to stacked corretly

ax.set_xlabel('Day fo Week')
ax.set_ylabel('Currently Sales')
ax.set_title('Sales per Days of Week')
ax.legend(title='year')

fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2 df_pivot = df_pivot.reindex(["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])  # Ordenação dos dias
#       4 fig, ax = plt.subplots(figsize=(10, 5))
# ----> 5 bottom = np.zeros(len(df_pivot))  # initial base zero
#       6 colors = {2020: "#EF4E23", 2021: "#053D4D", 2022: "#8CA4AC"}  # year collors
#       8 for year in [2020, 2021, 2022]:
#
# NameError: name 'np' is not defined

# %%
df_pivot = df_sales_week.pivot(index="year", columns="desc_weekday", values="currently_sales").fillna(0)

fig, ax = plt.subplots(figsize=(10, 5))
bottom = np.zeros(len(df_pivot))

for day in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]:
    ax.bar(df_pivot.index.astype(str), df_pivot[day], bottom=bottom, label=day)
    bottom += df_pivot[day]

ax.set_ylabel('Currently Sales')
ax.set_xlabel("Year")
ax.set_title("Sales per Years")
ax.legend(title="Days of Week", bbox_to_anchor=(1.05, 1), loc='upper left')

# Exibir o gráfico
plt.show()

# %% [markdown]
# **Insights**: It's possible verify Saturday and Sunday like the best days of week in the three years analyzed, this can indicate more no completed sales rate, therefore I should recommend increasing or to improve the support operation in these days.
# Furthermore, in general, there were evaluate on the time, except in variation: Tuesday (2021/2020) with -6.57 and  Thursday (2021/2020) with -11.41.

# %% [markdown]
# #### 4. Analysis Loss Performance

# %%
df_loss = query_execute('../analysis/4_loss_performance.sql')
display(df_loss)
# Out:
#     country  refund  cancelled  qtd_vendas  loss_performance
# 0    MEXICO      14          6         218             10.90
# 1       EUA       3          6          72              8.00
# 2    BRASIL     154        223        2801              7.43
# 3  COLOMBIA      59         86         721              4.97

# %%
chart_barh(
    df_loss['country'].astype(str), 
    df_loss['loss_performance'], 
    'Loss Performance Rate of Producer Country from Products wiht Signature Type', 
    'Country', 
    'Loss Performance Rate',
    '#053D4D'
)

# %%
chart_barh(
    df_loss['country'].astype(str), 
    df_loss['qtd_vendas'], 
    'Total Sales of Producer Country from Products wiht Signature Type', 
    'Country', 
    'Total Sales',
    '#EF4E23'
)

# %% [markdown]
# **Insights**: It's possible verify in this case, how much bigger is sales quantity, smaller is Loss Performance Rate, that it is the metrics (cancelations+refunds)/total_sales, so I understand that of payment models or other process in Brazil and Colombia is working better than Mexico and USA. I think can be consumption patterns related with region, because the most of sales are in South American countries, while other countries are localized in North American. My recommendation is trying better the consumption patterns in North American Countries, with propose to analyze if there are some different habits the people these countries.

# %% [markdown]
# #### 5. Retention Commission

# %%
df_retention = query_execute('../analysis/5_retention.sql')
display(df_retention)
# Out:
#    product_id                  niche  recovery_active  comission_received  \
# 0   218834610              Marketing                1           223743.00
# 1   328762963    Saúde e Alimentação                1            20623.20
# 2   466262361       Empreendedorismo                1            31840.00
# 3   264261718               Financas                1            17052.00
# 4   844949729       Empreendedorismo                1            41246.40
# 5   348532296               Financas                1            28328.80
# 6   903828613               Financas                1             4531.20
# 7   719732475  Tecnologia e Inovação                1           274922.88
# 8   545252229      Educação Infantil                0            20500.20
#
#    total_comission  average_commission_retention
# 0        258523.20                         86.55
# 1         24226.80                         85.13
# 2         38864.00                         81.93
# 3         21352.80                         79.86
# 4         51866.10                         79.52
# 5         35700.00                         79.35
# 6          6006.20                         75.44
# 7        364897.28                         75.34
# 8         28847.70                         71.06

# %%
chart_barv(
    df_retention.index + 1, 
    df_retention['average_commission_retention'], 
    '% Commission Retention of Course Type', 
    'Product Id', 
    'Average Comission Retention'
)

# %% [markdown]
# **Insights**: There're difference for product performance consididering products with the recovery tool activated, because all products listed. The retention smarllest was unique porduct without recovery tool activated, this reinforces use of tools, because there're less events with sales no completed. Besides of, there is a duality, in that, the best commission retention had the second position of total commission, and the biggest in total commission had the second worst position of commission retention. Possibly there are something to harm product sales performance.

# %% [markdown]
# #### 6. Analysis of Producers Part. 2

# %%
df_producers2 = query_execute('../analysis/6_top_producer2.sql')
display(df_producers2.head(10))
# Out:
#    producer_id   country  member_active_rate  avg_order_value  discount_rate  \
# 0           13    BRASIL               68.97          1602.64           6.17
# 1            1    BRASIL               43.60           437.85           6.15
# 2            4  COLOMBIA                9.58           523.54           5.92
# 3            3    BRASIL                0.00           291.41           6.16
# 4            6    MEXICO               40.20           486.51           5.62
# 5            2  COLOMBIA               31.27           478.81           6.27
# 6            7    BRASIL                0.00           346.77           5.13
# 7            8    BRASIL                0.00           352.46           7.31
# 8           14  COLOMBIA               17.46           120.11           7.11
# 9           10    BRASIL                0.00           142.35           5.47
#
#    recency  not_completed_sales_rate  frequency  revenue_expected
# 0      784                     14.19       1099         1761296.0
# 1      784                     16.78       3736         1635815.0
# 2      784                     22.82        793          415170.0
# 3      741                     21.84       1346          392236.0
# 4      784                     18.58        689          335204.0
# 5      784                     21.02        566          271008.0
# 6      784                     22.41        638          221240.0
# 7      784                     25.85        557          196323.0
# 8      784                     22.24        544           65340.0
# 9      784                     20.85        422           60072.0

# %%
chart_barv(
    df_producers2['producer_id'].astype(str), 
    df_producers2['revenue_expected']/1000, 
    'Total Revenue Expected since start like hotmart producer', 
    'Producer Id', 
    'Revenue Expected (Thous.)'
)

# %%
chart_barv(
    df_producers2['producer_id'].astype(str), 
    df_producers2['avg_order_value'], 
    'Average Order Value since start like hotmart producer', 
    'Producer Id', 
    'Revenue Average Order Value',
    '#053D4D'
)

# %% [markdown]
# **Insights**: I think mainly analyze RFV, that R is recency (days since last sale), F is frequency (volumetry of sales in period determinate) and V (it was considering revenue expected, that is, total revenue reconsidering sales not completed). For recency is important metric for evaluate the producers are active in platforms (always are selling), and frequency evaluate the constancy and volumetry of sales, very important for producers performance. Already the Revenue Expected metric was chosen, because I should want to analyze the potencial of producers together Sales Not Completed Rate. How this is it, I could analyze if there were producers sold well, but it was missing very many sales. Although, the best producer in meddle had lowest rate of sales not completed. For secondary metrics I placed three, it is:
# member_active_rate, avg_order_value e discount_rate. I chose this metrics, because for me it's important verify if correlation between with principal metrics. After analyze, concludes discount_rate metrics is similar with all producers (it's standard discounts), already member_active_rate and avg_order_value for the best producer (first position) is bigger than other, but in some cases it don't correlation with revenue or frequency, like producer 3, that is on 4th position and he don't have someone with member, and own 3th worst position with KPI avg_order_value.
# Finally, I try analyzing only year 2023, but there is only one producer/product sold in this year, this mode, I preferred use after 2019 onwards.

# %% [markdown]
# #### Recommendation actions

# %% [markdown]
# 1. In according with analysis realized, it was noticed very crucial to increase use the recovery active tool, because it is related with commission received rate.
# 2. Analyze culture and habits of consumers in different regions (benchmark), because it was sowing South American Countries is more effective than North American Countries.
# 3. Try work, when possible, with sales of signature products type, because almost all products have recovery active, and this to improve a lot of with sales.
# 4. Get more data about payment types, because I could analyze the best. It could make promotion or incentive the people payment with the best payment types, or merge this with other in the sales moment.
